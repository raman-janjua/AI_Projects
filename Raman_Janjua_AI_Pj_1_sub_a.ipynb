# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %% [markdown]
# # Project_1
# # 'Multiclass Multilabel Prediction For StackOverflow Questions'

# %%
# !wget https://www.dropbox.com/s/5721wcs2guuykzl/stacksample.zip
# Out:
# --2023-10-12 11:23:15--  https://www.dropbox.com/s/5721wcs2guuykzl/stacksample.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/5721wcs2guuykzl/stacksample.zip [following]
# --2023-10-12 11:23:15--  https://www.dropbox.com/s/raw/5721wcs2guuykzl/stacksample.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucbfd3919cd84393c5d657774741.dl.dropboxusercontent.com/cd/0/inline/CFe-cqKp2oZ_TR-BTj6TFpUAX-9reztDFlL-Us2sxc6NVR3NQm7R-gyAYqjFhJzJaqmx933VjaTR4a1uF--jnHAjGoC_Cq4PMd_gU3mtcfW5nCkW17nzOqCYQcSgwDnNLew/file# [following]
# ...

# %%
ls
# Out:
# sample_data/  stacksample.zip

# %%
# !unzip stacksample.zip
# Out:
# Archive:  stacksample.zip
#   inflating: Answers.csv
#   inflating: Questions.csv
#   inflating: Tags.csv

# %%
ls
# Out:
# Answers.csv  Questions.csv  sample_data/  stacksample.zip  Tags.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# magic function
# %matplotlib inline

# %%
# !ls
# Out:
# Answers.csv  Questions.csv  sample_data  stacksample.zip  Tags.csv

# %%
Ques_file=pd.read_csv("./Questions.csv",encoding='latin1')

# %%
Ques_file
# Out:
#                Id  OwnerUserId          CreationDate            ClosedDate  \
# 0              80         26.0  2008-08-01T13:57:07Z                   NaN
# 1              90         58.0  2008-08-01T14:41:24Z  2012-12-26T03:45:49Z
# 2             120         83.0  2008-08-01T15:50:08Z                   NaN
# 3             180    2089740.0  2008-08-01T18:42:19Z                   NaN
# 4             260         91.0  2008-08-01T23:22:08Z                   NaN
# ...           ...          ...                   ...                   ...
# 1264211  40143210    5610777.0  2016-10-19T23:38:01Z                   NaN
# 1264212  40143300    3791161.0  2016-10-19T23:48:09Z                   NaN
# 1264213  40143340    7028647.0  2016-10-19T23:52:50Z                   NaN
# 1264214  40143360     871677.0  2016-10-19T23:55:24Z                   NaN
# 1264215  40143380    6823982.0  2016-10-19T23:57:31Z                   NaN
#
#          Score                                              Title  \
# ...

# %%
Ques_file.drop('OwnerUserId', inplace=True, axis=1)

# %%
Ques_file.drop('CreationDate', inplace=True, axis=1)

# %%
Ques_file.drop('ClosedDate', inplace=True, axis=1)

# %%
Ques_file.drop('Score', inplace=True, axis=1)

# %%
Ques_file.head()
# Out:
#     Id                                              Title  \
# 0   80  SQLStatement.execute() - multiple queries in o...
# 1   90  Good branching and merging tutorials for Torto...
# 2  120                                  ASP.NET Site Maps
# 3  180                 Function for creating color wheels
# 4  260  Adding scripting functionality to .NET applica...
#
#                                                 Body
# 0  <p>I've written a database generation script i...
# 1  <p>Are there any really good tutorials explain...
# 2  <p>Has anyone got experience creating <strong>...
# 3  <p>This is something I've pseudo-solved many t...
# 4  <p>I have a little game written in C#. It uses...

# %%
Ques_file.tail()
# Out:
#                Id                                       Title  \
# 1264211  40143210                    URL routing in PHP (MVC)
# 1264212  40143300    Bigquery.Jobs.Insert - Resumable Upload?
# 1264213  40143340          Obfuscating code in android studio
# 1264214  40143360  How to fire function after v-model change?
# 1264215  40143380     npm run mocha test - files being cached
#
#                                                       Body
# 1264211  <p>I am building a custom MVC project and I ha...
# 1264212  <p>The API docs show that you should be able t...
# 1264213  <p>Under minifyEnabled I changed from false to...
# 1264214  <p>I have input which I use to filter my array...
# 1264215  <p>I'm running a mocha test and I noticed my c...

# %%
import re
def remove_html_tags(body):
    regex = re.compile('<.*?>')
    return re.sub(regex, '', body)
Ques_file['Body'] = Ques_file['Body'].apply(remove_html_tags)

# %%
Ques_file.to_csv('question_clean.csv',index=False)

# %%
Ques_clean=pd.read_csv("./question_clean.csv",encoding='latin1')

# %%
Ques_clean.head(5)
# Out:
#     Id                                              Title  \
# 0   80  SQLStatement.execute() - multiple queries in o...
# 1   90  Good branching and merging tutorials for Torto...
# 2  120                                  ASP.NET Site Maps
# 3  180                 Function for creating color wheels
# 4  260  Adding scripting functionality to .NET applica...
#
#                                                 Body
# 0  I've written a database generation script in S...
# 1  Are there any really good tutorials explaining...
# 2  Has anyone got experience creating SQL-based A...
# 3  This is something I've pseudo-solved many time...
# 4  I have a little game written in C#. It uses a ...

# %%
Tag_file=pd.read_csv("./Tags.csv",encoding='latin1')

# %%
Tag_file.head(10)
# Out:
#     Id                    Tag
# 0   80                   flex
# 1   80         actionscript-3
# 2   80                    air
# 3   90                    svn
# 4   90            tortoisesvn
# 5   90                 branch
# 6   90  branching-and-merging
# 7  120                    sql
# 8  120                asp.net
# 9  120                sitemap

# %%
import collections

# %%
tagCount =  collections.Counter(list(Tag_file['Tag'])).most_common(10)
print(tagCount)
# Out:
# [('javascript', 124155), ('java', 115212), ('c#', 101186), ('php', 98808), ('android', 90659), ('jquery', 78542), ('python', 64601), ('html', 58976), ('c++', 47591), ('ios', 47009)]

# %%
#Top_10_tags = pd.DataFrame(tagCount)
#Top_10_tags

# %%
#Top_10_tags.drop(1, inplace=True, axis=1)
#Top_10_tags

# %%
#JFR
#df2=Tag_file.loc[Tag_file['Tag'] == 'javascript', 'Id']
#print(df2)

# %%
#JFR
#tagCount[2][0]

# %%
#JFR
#Top_10_tags = Tag_file['Tag'].value_counts().nlargest(10)

# %%
Top_10_tags=['javascript','java','c#','php','android','jquery','python','html','c++','ios']

# %%
Tag_IDs_top10= Tag_file[Tag_file.Tag.isin(Top_10_tags)]
print (Tag_IDs_top10.shape)
# Out:
# (826739, 2)

# %%
Tag_IDs_top10.head(10)
# Out:
#       Id   Tag
# 14   260    c#
# 18   330   c++
# 28   650    c#
# 35   930    c#
# 39  1010    c#
# 41  1040    c#
# 61  1760    c#
# 74  2250    c#
# 79  2530  html
# 97  2780    c#

# %%
def add_tags(Ques_file):
    return Tag_IDs_top10[Tag_IDs_top10['Id'] == Ques_file['Id']].Tag.values

Top_10_Ids = Tag_IDs_top10.apply(add_tags, axis=1)

# %%
Top_10_Ids
# Out:
# 14                 [c#]
# 18                [c++]
# 28                 [c#]
# 35                 [c#]
# 39                 [c#]
#                ...
# 3750974    [javascript]
# 3750981        [python]
# 3750984           [php]
# 3750987       [android]
# 3750989    [javascript]
# Length: 826739, dtype: object

# %%
#len(Top_10_Ids),Tag_IDs_top10.shape

# %%
Tag_IDs_top10=pd.concat([Tag_IDs_top10, Top_10_Ids.rename('Tags')], axis=1)
Tag_IDs_top10.head()
# Out:
#       Id  Tag   Tags
# 14   260   c#   [c#]
# 18   330  c++  [c++]
# 28   650   c#   [c#]
# 35   930   c#   [c#]
# 39  1010   c#   [c#]

# %%
Tag_IDs_top10.drop(["Tag"], axis=1, inplace=True)
Tag_IDs_top10.shape
# Out:
# (826739, 2)

# %%
Tag_IDs_top10.head(5)
# Out:
#       Id   Tags
# 14   260   [c#]
# 18   330  [c++]
# 28   650   [c#]
# 35   930   [c#]
# 39  1010   [c#]

# %%
Top_Ten_tags=Tag_IDs_top10.loc[Tag_IDs_top10.astype(str).drop_duplicates().index]

# %%
Top_Ten_tags
# Out:
#                Id          Tags
# 14            260          [c#]
# 18            330         [c++]
# 28            650          [c#]
# 35            930          [c#]
# 39           1010          [c#]
# ...           ...           ...
# 3750974  40143150  [javascript]
# 3750981  40143190      [python]
# 3750984  40143210         [php]
# 3750987  40143340     [android]
# 3750989  40143360  [javascript]
#
# [706336 rows x 2 columns]

# %%
Final_file=pd.merge(Ques_file, Top_Ten_tags, on='Id')
print(Final_file.shape)
Final_file.head()
# Out:
# (706336, 4)
#      Id                                              Title  \
# 0   260  Adding scripting functionality to .NET applica...
# 1   330          Should I use nested classes in this case?
# 2   650                Automatically update version number
# 3   930  How do I connect to a database and loop over a...
# 4  1010  How to get the value of built, encoded ViewState?
#
#                                                 Body   Tags
# 0  I have a little game written in C#. It uses a ...   [c#]
# 1  I am working on a collection of classes used f...  [c++]
# 2  I would like the version property of my applic...   [c#]
# 3  What's the simplest way to connect and query a...   [c#]
# 4  I need to grab the base64-encoded representati...   [c#]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
from nltk import word_tokenize
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence


from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding, BatchNormalization, GRU ,concatenate
from keras.models import Model

# %%
multilabel_binarizer = MultiLabelBinarizer()
multilabel_binarizer.fit(Final_file.Tags)
labels = multilabel_binarizer.classes_
labels
# Out:
# array(['android', 'c#', 'c++', 'html', 'ios', 'java', 'javascript',
#        'jquery', 'php', 'python'], dtype=object)

# %%
train,test=train_test_split(Final_file,test_size=0.25,random_state=24)

# %%
train.shape,test.shape
# Out:
# ((529752, 4), (176584, 4))

# %%
X_train_t=train['Title']
X_train_b=train['Body']
y_train=multilabel_binarizer.transform(train['Tags'])
X_test_t=test['Title']
X_test_b=test['Body']
y_test=multilabel_binarizer.transform(test['Tags'])

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sent_lens_t=[]
for sent in train['Title']:
    sent_lens_t.append(len(word_tokenize(sent)))
max(sent_lens_t)
# Out:
# 60

# %%
import numpy as np

# %%
np.quantile(sent_lens_t,0.80)
# Out:
# 12.0

# %%
max_len_t = 12
tok = Tokenizer(char_level=False,split=' ')
tok.fit_on_texts(X_train_t)
sequences_train_t = tok.texts_to_sequences(X_train_t)

# %%
vocab_len_t=len(tok.index_word.keys())
vocab_len_t
# Out:
# 82593

# %%
# !pip install pad_sequences
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pad_sequences: filename=pad_sequences-0.6.1-py3-none-any.whl size=10199 sha256=e2acfc1473d9aa6de61a450cac0ac94865272ef8288abbdb71361d48fdeb7868
#   Stored in directory: /root/.cache/pip/wheels/48/9d/22/0a6305b87a9cc46ccc032060a041c3b59f39ac462f7358997e
# Successfully built pad_sequences
# ...

# %%
from keras.utils import pad_sequences

print(pad_sequences)
# Out:
# <function pad_sequences at 0x7efdf873ff40>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
sequences_matrix_train_t = sequence.pad_sequences(sequences_train_t,maxlen=max_len_t)
sequences_matrix_train_t
# Out:
# array([[    0,     0,     0, ...,    39, 13295, 35156],
#        [    0,     0,     0, ...,   435,   326,    23],
#        [    0,     0,     0, ...,   620,    14,  3998],
#        ...,
#        [    0,     0,     0, ...,    10,    74,  2835],
#        [    0,     0,     0, ...,     2,    18,    81],
#        [    0,     0,     0, ..., 14559,   794,   245]], dtype=int32)

# %%
sequences_test_t = tok.texts_to_sequences(X_test_t)
sequences_matrix_test_t = sequence.pad_sequences(sequences_test_t,maxlen=max_len_t)

# %%
sequences_matrix_train_t.shape,sequences_matrix_test_t.shape,y_train.shape,y_test.shape
# Out:
# ((529752, 12), (176584, 12), (529752, 10), (176584, 10))

# %%
sent_lens_b=[]
for sent in train['Body']:
    sent_lens_b.append(len(word_tokenize(sent)))
max(sent_lens_b)
# Out:
# 14682

# %%
np.quantile(sent_lens_b,0.60)
# Out:
# 232.0

# %%
max_len_b = 232
tok = Tokenizer(char_level=False,split=' ')
tok.fit_on_texts(X_train_b)
sequences_train_b = tok.texts_to_sequences(X_train_b)

# %%
vocab_len_b =len(tok.index_word.keys())
vocab_len_b
# Out:
# 1655486

# %%
sequences_matrix_train_b = sequence.pad_sequences(sequences_train_b,maxlen=max_len_b)
sequences_matrix_train_b
# Out:
# array([[     0,      0,      0, ...,    394,   2876, 881084],
#        [     0,      0,      0, ...,      2,     56, 126139],
#        [     0,      0,      0, ...,      9,   3514,   3577],
#        ...,
#        [     0,      0,      0, ...,     24,     72,    738],
#        [     0,      0,      0, ...,    202,     62,     10],
#        [     0,      0,      0, ...,    182,    203,     10]], dtype=int32)

# %%
sequences_test_b = tok.texts_to_sequences(X_test_b)
sequences_matrix_test_b = sequence.pad_sequences(sequences_test_b,maxlen=max_len_b)

# %%
sequences_matrix_train_t.shape,sequences_matrix_train_b.shape,y_train.shape
# Out:
# ((529752, 12), (529752, 232), (529752, 10))

# %%
def RNN():
    # Title Only
    title_input = Input(name='title_input',shape=[max_len_t])
    title_Embed = Embedding(vocab_len_t+1,1500,input_length=max_len_t,mask_zero=True,name='title_Embed')(title_input)
    gru_out_t = GRU(100)(title_Embed)
    # auxiliary output to tune GRU weights smoothly
    auxiliary_output = Dense(10, activation='sigmoid', name='aux_output')(gru_out_t)

    # Body Only
    body_input = Input(name='body_input',shape=[max_len_b])
    body_Embed = Embedding(vocab_len_b+1,175,input_length=max_len_b,mask_zero=True,name='body_Embed')(body_input)
    gru_out_b = GRU(50)(body_Embed)

    # combined with GRU output
    com = concatenate([gru_out_t, gru_out_b])

    # now the combined data is being fed to dense layers
    dense1 = Dense(200,activation='relu')(com)
    dp1 = Dropout(0.5)(dense1)
    bn = BatchNormalization()(dp1)
    dense2 = Dense(100,activation='relu')(bn)

    main_output = Dense(10, activation='sigmoid', name='main_output')(dense2)

    model = Model(inputs=[title_input, body_input],outputs=[main_output, auxiliary_output])
    return model

# %%
model = RNN()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  title_input (InputLayer)    [(None, 12)]                 0         []
#
#  body_input (InputLayer)     [(None, 232)]                0         []
#
#  title_Embed (Embedding)     (None, 12, 1500)             1238910   ['title_input[0][0]']
#                                                           00
#
#  body_Embed (Embedding)      (None, 232, 175)             2897102   ['body_input[0][0]']
#                                                           25
#
#  gru (GRU)                   (None, 100)                  480600    ['title_Embed[0][0]']
#
#  gru_1 (GRU)                 (None, 50)                   34050     ['body_Embed[0][0]']
#
#  concatenate (Concatenate)   (None, 150)                  0         ['gru[0][0]',
# ...

# %%
model.compile(optimizer='adam',loss={'main_output': 'categorical_crossentropy', 'aux_output': 'categorical_crossentropy'},
              metrics=['accuracy'])

# %%
results=model.fit({'title_input': sequences_matrix_train_t, 'body_input': sequences_matrix_train_b},
          {'main_output': y_train, 'aux_output': y_train},
          validation_data=[{'title_input': sequences_matrix_test_t, 'body_input': sequences_matrix_test_b},
          {'main_output': y_test, 'aux_output': y_test}],
          epochs=2, batch_size=200)
# Out:
# Epoch 1/2
#   33/2649 [..............................] - ETA: 11:21:00 - loss: 5.0529 - main_output_loss: 2.4072 - aux_output_loss: 2.6457 - main_output_accuracy: 0.2838 - aux_output_accuracy: 0.2274
